# %% [markdown]
# Subject:
# Data Exploration & Visualization using Python II
# Term 2 – Project
#
# Submitted by:
# Agathiyan K
# 045005
#
# Submitted to:
# Prof. Amarnath Mitra
#
#
# About the Dataset:
#
# The dataset encompasses a comprehensive record of Indian Premier League (IPL) cricket matches, covering the period from 2008 to 2019. The IPL, a premier professional T20 cricket league in India, has gained immense popularity worldwide for its dynamic and entertaining format. The dataset comprises individual rows representing specific matches, while numerous parameters provide intricate details about each encounter, offering a rich source for in-depth analysis and insights into the tournament's history.
#
# The key parameters used in the dataset:
#
#
# City: The dataset includes the location or city where each match was conducted, reflecting the widespread appeal of the IPL across different regions.
#
# Date: The date parameter captures the chronological order of matches, allowing for temporal analyses and trend identification.
#
# Day: Indicating the day of the week when matches occurred, this parameter adds a temporal dimension to the dataset.
#
# Year: Recognizing the IPL season in which a match took place, allowing for analyses spanning across different seasons.
#
# Team 1 and Team 2: Identifying the participating teams in each match, crucial for understanding team dynamics and performance trends.
#
# Toss Winner and Toss Decision: Offering insights into the strategic decisions made by teams, with information on which team won the toss and their subsequent decision to bat or field.
#
# Result: Indicating the outcome of each match, including classifications such as 'normal,' 'tie,' or 'no result,' providing a comprehensive overview of match results.
#
# Winner: Identifying the team emerging victorious in each match, enabling analyses of team success rates and overall tournament performance.
#
# Player of the Match: Recognizing standout individual performances, highlighting exceptional players in each match.
#
# Venue: Capturing the stadium where matches were held, crucial for understanding venue preferences, team dynamics in specific locations, and assessing the popularity of cricket across various cities.
#
# Umpire: Recognizing the umpires overseeing each match, adding a layer of officiating information to the dataset.

# %% [markdown]
# -------------------------------------------------------------------

# %% [markdown]
# Report
#
# Insights:
#
# From total matches won:
#
# Consistency and Dominance:
#    Chennai Super Kings (CSK) stands out as the most consistently successful team, maintaining a high number of victories each year. Their steady increase in cumulative wins reflects sustained excellence.
#
#
# Variance in Performances:
#       Teams like Sunrisers Hyderabad and Mumbai Indians showcase a pattern of consistent improvement over the years, indicating effective team management and strategic planning.
#
#
# Success of Established Franchises:
#       Traditional and long-standing franchises like Mumbai Indians and Kolkata Knight Riders have consistently performed well, showcasing a combination of legacy and adaptability.
#
#
# Impact of Player Auctions and Transfers:
#         Changes in team dynamics due to player auctions and transfers can influence performance. Teams should analyze the impact of such changes on their cumulative win counts.
#
#
#
# Winners and Runners Chart:
#
# CSK Dominance: CSK has been the most successful team, consistently reaching the finals and securing multiple victories. Their managerial approach, team composition, and leadership have contributed to this dominance.
#
# Mumbai Indians' Consistency: Mumbai Indians' consistent performance, with a balance of titles and runner-up positions, suggests effective team management and strategic planning.
#
# KKR's Balanced Performance: Kolkata Knight Riders have a balanced record with both victories and runner-up positions, indicating stability and competitiveness.
#
# Royal Challengers Bangalore's Quest: RCB has reached the runner-up position multiple times but has not secured an IPL title. Evaluating and refining strategies for crucial moments could enhance their chances of lifting the trophy.
#
# The cumulative data on runner-up positions complements the winners' dataset, providing a holistic view of each team's consistency and overall performance.
#
#
# Chart on which day IPL matches played most:
#
# Popular Match Days:
#       Sundays: Throughout the years, Sundays consistently have the highest number of matches. This indicates that Sunday is a preferred day for scheduling IPL matches, possibly due to higher viewership on weekends.
#       Saturdays: Saturdays also have a significant number of matches, making it another popular day for IPL fixtures.
#
#
# Consistency Across Years:
#         The data shows a gradual increase in the total number of matches played each year. This consistency suggests a steady growth and sustained interest in the IPL tournament over the years.
#
#
# Weekday Trends:
#         Weekdays, particularly Mondays and Tuesdays, generally have lower match counts compared to weekends. This might be attributed to people being more occupied with work on weekdays.
#
#
# Strategic Scheduling:
#           The insights gained from this data could be valuable for IPL organizers in strategically scheduling matches to maximize viewership and attendance. For example, placing high-profile matches on Sundays or Saturdays could potentially attract more attention.
#
#
#
# Stadium and number of matches occured:
#
# Popular Venues:
#          Eden Gardens, Kolkata: Eden Gardens consistently hosted the highest number of matches each year. This suggests that Eden Gardens is a popular and preferred venue for IPL matches.
#         M Chinnaswamy Stadium, Bangalore: This stadium also witnessed a significant number of matches throughout the years, making it one of the preferred venues.
#
#
# Facility Management:
#         Stadiums that consistently host a high number of matches need to manage their facilities efficiently to cater to the demands of regular IPL matches. This includes aspects like pitch maintenance, seating capacity, security, and amenities.
#
#
# Strategic Venue Selection:
#         Knowledge of the popularity of venues can help IPL organizers strategically select venues for matches. High-profile or crucial matches could be scheduled at stadiums known for attracting larger crowds.
#
#
#
# Tosses Won by IPL Teams Over the Years
#
# Toss Dominance:
#         Mumbai Indians (MI): MI consistently dominated in winning tosses throughout the years. This suggests a certain level of strategic advantage as they often had the opportunity to choose whether to bat or bowl first.
#         Chennai Super Kings (CSK): CSK also maintained a strong record in winning tosses, indicating their captain's success in the toss decision.
#
#
# Impact on Match Results:
#         Winning the toss can influence match outcomes, especially in T20 cricket. Teams winning the toss have the option to choose based on pitch conditions, weather, and their strengths, potentially impacting the overall game.
#
#
# Strategic Decision-Making:
#         The toss-winning captain has the choice to bat or bowl first, and this decision depends on various factors. Teams that consistently win tosses may have a strategic advantage in adapting to match conditions.
#
#
#
# Teams Choosing to Bat:
#
#    Consistent Leadership:
#         Chennai Super Kings (CSK): CSK consistently chose to bat more often than other teams, showcasing a preference for setting a target or chasing.
#
#   Strategic Decisions:
#         Teams like Kolkata Knight Riders (KKR) and Mumbai Indians (MI) have shown a balance between choosing to bat and field, suggesting adaptability to match conditions.
#
#   Evolution Over Years:
#         Teams like Delhi Capitals and Royal Challengers Bangalore (RCB) seem to have evolved their strategies over the years, choosing to bat more often in recent seasons.
#
#
# Teams Choosing to Field:
#
#    Adaptability and Bowling Strength:
#         Teams like Sunrisers Hyderabad (SRH) and Rajasthan Royals (RR) have frequently chosen to field, indicating confidence in their bowling line-up or adaptability to chase.
#
#    Defending Strength:
#         Teams opting to field might have confidence in their ability to restrict opponents' scores, showcasing a strong bowling unit.
#
#    Aggressive Tactics:
#         Kolkata Knight Riders (KKR) and Mumbai Indians (MI) have balanced their approach, choosing to field more often in some seasons, suggesting an aggressive mindset.
#
#
# Teams have generally maintained a consistent approach to choosing whether to bat or field over the years. Flexibility in decision-making is crucial in T20 cricket, and teams seem to adapt their strategies based on conditions, opponents, and team strengths.
#
#
#
# Conclusion:
#
# In analyzing the data on toss-winning decisions in the IPL, several strategic patterns and trends emerge. Teams appear to adopt diverse approaches when choosing between batting and fielding after winning the toss. This decision-making process is likely influenced by the leadership style of the team captain, with some teams consistently favoring a specific strategy over the years, such as Chennai Super Kings (CSK), while others, like Delhi Capitals and Royal Challengers Bangalore, exhibit adaptability. The frequency of teams opting to bat or field suggests a reliance on perceived strengths, confidence in bowling capabilities, and strategic preferences for chasing targets. Notably, teams like Kolkata Knight Riders (KKR) and Mumbai Indians (MI) maintain a balanced approach, demonstrating flexibility based on match-specific factors. The evolution of these strategies over the years underscores the dynamic nature of T20 cricket, with teams adjusting their tactics in response to changes in captaincy, team composition, and overall tournament dynamics. Understanding these nuances is crucial for effective team management, allowing teams to optimize their decision-making processes and stay competitive in the dynamic landscape of the IPL.

# %%
'''
Reference:
1. ChatGPT
2. https://www.youtube.com/watch?v=Dawp5XOSEuk
'''
# Out:
# '\nReference:\n1. ChatGPT\n2. https://www.youtube.com/watch?v=Dawp5XOSEuk\n'

# %%
# !pip install bar_chart_race
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 3.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import bar_chart_race as bcr
from google.colab import files

# %%
# Upload the Excel file
uploaded = files.upload()

# Get the file name from the uploaded files
file_name = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-31f1ace5-ac98-4078-8272-d303f5b26873" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31f1ace5-ac98-4078-8272-d303f5b26873">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Use pd.read_excel to read data from a specific sheet
df_matches_won = pd.read_excel(file_name, sheet_name="matches_won")

# Remove the "Row Labels" and "Grand Total" columns
df_matches_won = df_matches_won.drop(["Row Labels"], axis=1)

# Adjust the figure size to indirectly control bar width
fig_size = (5, 3)  # You can adjust the values based on your preference

# Create the race chart
bcr.bar_chart_race(df=df_matches_won, title="IPL Team Performance Over the Years", figsize=fig_size, period_length=1000, period_label={'x': 0.99, 'y': 0.12, 'ha': 'right'},
                    steps_per_period=1, interpolate_period=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="910" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# Objective:
# The objective of this dataset is to analyze the cumulative performance of different IPL teams over the years, focusing on the total number of matches won by each team in the period from 2008 to 2019. The cumulative sums provide a comprehensive view of the teams' consistency and success throughout these twelve seasons.
#
# Analysis:
#
#   Chennai Super Kings (CSK): CSK consistently performed well, maintaining a strong position in terms of match victories. Their cumulative wins steadily increased, reaching 100 by the end of 2019, showcasing their dominance in the IPL.
#
#   Mumbai Indians (MI): MI also demonstrated a commendable performance, with a consistent upward trend in cumulative wins. They stood out as one of the most successful teams, closely competing with CSK throughout the years.
#
#   Kolkata Knight Riders (KKR): KKR showcased a balanced performance, gradually increasing their cumulative wins. The team's adaptability and strategic approach allowed them to remain competitive in the IPL.
#
#   Royal Challengers Bangalore (RCB): RCB's cumulative wins showed some variability, suggesting periods of success and challenges. Despite fluctuations, they remained a competitive force in the league.
#
#   Kings XI Punjab: Kings XI Punjab's performance demonstrated moderate success, with a steady growth in cumulative wins over the seasons.
#
#   Delhi Capitals: Formerly Delhi Daredevils, the team, rebranded as Delhi Capitals, showed improvement in cumulative wins over the years, indicating positive developments in their performance.
#
#   Rajasthan Royals: Rajasthan Royals displayed a fluctuating performance, facing challenges in certain seasons but contributing to the league with notable victories.
#
#   Sunrisers Hyderabad: Sunrisers Hyderabad emerged as a competitive team, steadily increasing their cumulative wins and establishing themselves as a force to be reckoned with.
#
#
# Interpretation:
# The cumulative wins data provides insights into the long-term success and consistency of each IPL team. It highlights the dominance of CSK and MI, the competitive spirit of KKR, and the evolving performance of teams like Delhi Capitals and Sunrisers Hyderabad. Fluctuations in cumulative wins for certain teams reflect the dynamic nature of T20 cricket and the need for strategic adjustments over the years. This analysis is valuable for team management, allowing them to understand historical performance trends and make informed decisions to enhance future competitiveness in the IPL.

# %%
# Use pd.read_excel to read data from a specific sheet
df_winners = pd.read_excel(file_name, sheet_name="winner")

# Remove the "Row Labels" column
df_winners = df_winners.drop("Row Labels", axis=1)
# Adjust the figure size to indirectly control bar width
fig_size = (3, 3)  # You can adjust the values based on your preference

# Create the race chart for matches played on each day of the week
bcr.bar_chart_race(df=df_winners, title="Winners of IPL", figsize=fig_size,
                    period_length=1000, period_label={'x': 0.99, 'y': 0.12, 'ha': 'right'},
                    steps_per_period=1, interpolate_period=False, bar_kwargs={'alpha': 0.7})
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="622" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# Objective:
# The objective of this dataset is to examine the cumulative number of IPL trophies won by each team from the inaugural season in 2008 to the 2019 season. The data provides insights into the overall success and championship achievements of the participating teams over the years.
#
# Analysis:
#
#   Chennai Super Kings (CSK): CSK demonstrated a remarkable performance in winning IPL trophies. Their consistent success is evident in the steady increase of cumulative trophies, reaching three by the end of 2019.
#
#   Mumbai Indians (MI): MI displayed a highly successful campaign, with a gradual rise in cumulative trophies, culminating in four championships by the conclusion of the 2019 season.
#
#   Kolkata Knight Riders (KKR): KKR secured two IPL trophies, showcasing their competitiveness and ability to clinch the title in multiple seasons.
#
#   Sunrisers Hyderabad: Sunrisers Hyderabad claimed the IPL trophy twice, establishing themselves as a formidable team with consistent performances.
#
#   Rajasthan Royals: Rajasthan Royals won the inaugural IPL trophy in 2008, but their cumulative count remained unchanged beyond that season.
#
#   Delhi Capitals: Formerly Delhi Daredevils, the team, rebranded as Delhi Capitals, did not secure an IPL trophy during the analyzed period.
#
#   Kings XI Punjab and Royal Challengers Bangalore: These teams did not secure an IPL trophy during the examined seasons.
#
# Interpretation:
# The data on cumulative IPL trophies provides a snapshot of the championship success of each team. It highlights the dominance of CSK and MI, the multi-time champions, and the ability of KKR and Sunrisers Hyderabad to secure multiple titles. The dataset also reflects the challenges faced by several teams in clinching the IPL trophy, emphasizing the competitive nature of the tournament. This analysis can be valuable for fans, team management, and stakeholders, offering a historical perspective on team achievements in the IPL.

# %%
# Use pd.read_excel to read data from a specific sheet
df_runners = pd.read_excel(file_name, sheet_name="runner")

# Remove the "Row Labels" column
df_runners = df_runners.drop("Row Labels", axis=1)
# Adjust the figure size to indirectly control bar width
fig_size = (3, 3)  # You can adjust the values based on your preference

# Create the race chart for matches played on each day of the week
bcr.bar_chart_race(df=df_runners, title="Runners of IPL", figsize=fig_size,
                    period_length=1000, period_label={'x': 0.99, 'y': 0.12, 'ha': 'right'},
                    steps_per_period=1, interpolate_period=False, bar_kwargs={'alpha': 0.7})
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="622" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# Objective:
# The objective of this dataset is to analyze the cumulative number of times each IPL team has finished as the runner-up (second place) in the tournament from the inaugural season in 2008 to the 2019 season. This dataset provides insights into the consistent performance of teams reaching the finals but falling short of winning the championship.
#
# Analysis:
#
#   Chennai Super Kings (CSK): CSK has been the runner-up in five seasons, showcasing their remarkable consistency in reaching the final but falling short of securing the championship.
#
#   Mumbai Indians (MI): MI finished as the runner-up three times, indicating their regular presence in the IPL finals, with the team managing to clinch the title on multiple occasions.
#
#   Kolkata Knight Riders (KKR): KKR secured the runner-up position in four seasons, highlighting their competitiveness and frequent appearances in the final matches.
#
#   Royal Challengers Bangalore (RCB): RCB reached the final three times but remained the runner-up without winning the championship during the analyzed period.
#
#   Rajasthan Royals: Rajasthan Royals finished as the runner-up once in the 2008 season but did not achieve the same feat in subsequent seasons.
#
#   Sunrisers Hyderabad, Delhi Capitals, Kings XI Punjab: These teams did not secure the runner-up position during the examined seasons.
#
# Interpretation:
# The data on cumulative runner-up positions reflects the consistent performance of certain teams in reaching the IPL finals. CSK, MI, and KKR stand out as teams with multiple runner-up finishes, showcasing their ability to consistently reach the final stages of the tournament. The dataset also highlights the competitive nature of the IPL, with multiple teams making it to the final but falling short of winning the championship. This analysis provides valuable insights for fans, team management, and stakeholders, offering a historical perspective on team performances in reaching the final but finishing as the runner-up.

# %%
# Use pd.read_excel to read data from a specific sheet
df_players = pd.read_excel(file_name, sheet_name="player of match")

# Remove the "Row Labels" column
df_players = df_players.drop("Row Labels", axis=1)

# Sum the counts across all years for each player
df_players_total = df_players.sum(axis=0)

# Sort players based on total counts in descending order
df_players_total_sorted = df_players_total.sort_values(ascending=False)

# Select the top 20 players
top_players = df_players[df_players_total_sorted.index[:15]]

# Adjust the figure size to indirectly control bar width
fig_size = (6, 3)  # You can adjust the values based on your preference

# Create the race chart with improved settings for the top 20 players
bcr.bar_chart_race(df=top_players, title="Player of the Match Awards Won by Top 15 Players Over the Years", figsize=fig_size, period_length=1000, period_label={'x': 0.99, 'y': 0.12, 'ha': 'right'},
                    steps_per_period=1, interpolate_period=False, bar_kwargs={'alpha': 0.5})
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="944" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# Objective:
# The dataset aims to capture the cumulative sum of "Man of the Match" awards received by various cricket players in the Indian Premier League (IPL) from 2008 to 2019. The goal is to analyze the consistency and dominance of individual players in receiving these awards over the specified period.
#
# Analysis:
#
#   Player Performance Over Years:
#         The dataset provides a comprehensive view of player performance by showcasing the cumulative "Man of the Match" awards earned by each player from 2008 to 2019.
#         Examining the progression of awards over the years helps identify trends in player dominance and consistency.
#
#   Key Players:
#         Players with consistently high cumulative counts are likely to be key contributors to their respective teams, showcasing their impact across multiple seasons.
#         Observing which players maintain high counts across several years indicates a sustained level of excellence.
#
#   Seasonal Variations:
#         Variations in award counts from year to year may highlight specific seasons where certain players had exceptional performances.
#         Understanding these variations can provide insights into the dynamic nature of player contributions in different IPL editions.
#
#   Comparison Between Players:
#         The dataset enables a direct comparison between players in terms of their cumulative "Man of the Match" awards.
#         Comparing the counts can help identify players who consistently outperformed their peers and had a significant influence on match outcomes.
#
# Interpretation:
#
#   Consistent Performers:
#         Players with a steady increase in cumulative awards demonstrate consistency in delivering standout performances across multiple IPL seasons.
#
#   Dominant Players:
#         Players with the highest cumulative counts are considered dominant, having consistently been recognized as the best performers in various matches over the years.
#
#   Impact on Team Success:
#         Players with high award counts likely played crucial roles in their team's success, contributing significantly to victories.
#
#   Evolution of Player Dominance:
#         Tracking the changes in award counts over the years reveals the evolution of player dominance, indicating which players maintained or improved their performance levels.
#
#   Fan Favorites and Player Popularity:
#         Players with frequent "Man of the Match" awards may have become fan favorites, contributing to the overall excitement and popularity of the IPL.
#
#
#  ###############
#
#   Observations and Comments on Top Players:
#
#    Chris Gayle:
#         Consistent Dominance: Chris Gayle exhibits consistent dominance, topping the chart in multiple seasons.
#         Impactful Performances: His explosive batting style and remarkable innings contribute significantly to his high award count.
#
#    AB de Villiers:
#         Versatile Excellence: AB de Villiers stands out as a versatile player, consistently delivering exceptional performances with both bat and fielding.
#         Consistency Across Seasons: His ability to adapt and perform well in various seasons makes him a valuable asset to his team.
#
#    David Warner:
#         Captain's Influence: Warner's leadership role as a captain doesn't diminish his individual performance, evident from his consistent presence among the top performers.
#         Consistent Run-Scorer: Known for his aggressive yet effective batting, Warner is a key run-scorer for his team.
#
#    MS Dhoni:
#         Captain Cool's Impact: MS Dhoni, known for his captaincy skills, also showcases consistent individual brilliance.
#         Finisher's Prowess: His ability to finish matches under pressure contributes to his high "Man of the Match" awards.
#
#    Rohit Sharma:
#         Captaincy and Batting Combo: Rohit Sharma's dual role as a captain and a top-order batsman reflects in his cumulative awards.
#         Big Innings Contributor: He often plays crucial innings, steering the team to victory and earning individual recognition.
#
#    Virat Kohli:
#         Run-Machine: Virat Kohli, known for his prolific batting, consistently secures a place among the top performers.
#         Impactful Captain: His leadership role enhances his overall impact on matches and contributes to his high award count.
#
#    Suresh Raina:
#         Mr. IPL: Suresh Raina, often referred to as Mr. IPL, maintains a notable presence in the top performers' list.
#         Versatility: A versatile player, Raina's contributions in batting and fielding make him a valuable asset for his team.
#
#    Andre Russell:
#         All-Round Brilliance: Andre Russell's prowess as an all-rounder, combining explosive batting with effective bowling, earns him consistent recognition.
#         Game-Changer: His ability to turn the game in favor of his team makes him a match-winner and a favorite for the "Man of the Match."

# %%
# Use pd.read_excel to read data from a specific sheet
df_referees = pd.read_excel(file_name, sheet_name="year vs match refree")

# Remove the "Row Labels" column
df_referees = df_referees.drop("Row Labels", axis=1)

# Sum the counts across all years for each referee
df_referees_total = df_referees.sum(axis=0)

# Sort referees based on total counts in descending order
df_referees_total_sorted = df_referees_total.sort_values(ascending=False)

# Select the top referees (adjust the number as needed)
top_referees = df_referees[df_referees_total_sorted.index[:10]]

# Adjust the figure size to indirectly control bar width
fig_size = (7, 3)  # You can adjust the values based on your preference

# Create the race chart with improved settings for the top referees
bcr.bar_chart_race(df=top_referees, title="Top 5 Referees who refereed most Over the Years", figsize=fig_size, period_length=1000, period_label={'x': 0.99, 'y': 0.12, 'ha': 'right'},
                    steps_per_period=1, interpolate_period=False, bar_kwargs={'alpha': 0.7})
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="1128" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# Observations and Comments on Top Umpires:
#
#    Aleem Dar:
#         Consistent Presence: Aleem Dar maintains a consistent presence as one of the top umpires, showcasing reliability and experience.
#         Years of Service: His significant number of matches officiated across the years reflects his longevity and trustworthiness in the role.
#
#    HDPK Dharmasena:
#         Rising in Prominence: Dharmasena's umpiring career shows a steady rise, with an increasing number of matches officiated each year.
#         Versatile Officiating: He handles a diverse set of matches, demonstrating versatility in managing different teams and game situations.
#
#    M Erasmus:
#         Steady Contribution: Erasmus consistently contributes as a top umpire, with a gradual increase in matches officiated.
#         Global Presence: His involvement in various editions of the IPL underlines his international standing as an umpire.
#
#    CB Gaffaney:
#         Progressive Officiating: Gaffaney's umpiring career sees progression, indicating the recognition of his skills over the years.
#         Handling Pressure Situations: Officiating in crucial matches, he proves his ability to handle high-pressure situations with composure.
#
#    Nitin Menon:
#         Emerging Talent: Nitin Menon emerges as a promising umpire, with a noticeable increase in matches officiated.
#         Consistency in Performance: His consistent presence in recent years suggests a reliable and efficient performance as an umpire.
#
#    S Ravi:
#         Longevity and Consistency: S Ravi's long and consistent umpiring career is evident in his sustained presence among the top officials.
#         Experience Across Seasons: Officiating in multiple seasons showcases his adaptability and understanding of the evolving dynamics of the IPL.
#
#    BF Bowden:
#         Early Prominence: Though Bowden's officiating decreases over the years, his early presence in significant matches is notable.
#         Contribution to Early IPL: Being part of the initial seasons, he played a role in shaping the early narrative of the IPL.
#
#    RE Koertzen:
#         Early Peak: Koertzen's peak in the early seasons signifies his impact on the league during its formative years.
#         Years of Experience: Having officiated in multiple seasons, he contributed to the establishment of a fair and professional umpiring standard in the IPL.

# %%
# Use pd.read_excel to read data from a specific sheet
df_match_days = pd.read_excel(file_name, sheet_name="day")

# Remove the "Row Labels" column
df_match_days = df_match_days.drop("Row Labels", axis=1)
# Adjust the figure size to indirectly control bar width
fig_size = (3, 3)  # You can adjust the values based on your preference

# Create the race chart for matches played on each day of the week
bcr.bar_chart_race(df=df_match_days, title="Which Day matches player most", figsize=fig_size,
                    period_length=1000, period_label={'x': 0.99, 'y': 0.12, 'ha': 'right'},
                    steps_per_period=1, interpolate_period=False, bar_kwargs={'alpha': 0.7})
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="502" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# Objective:
# The objective of this dataset is to analyze and understand the distribution of Indian Premier League (IPL) matches across different days of the week over the years. The dataset provides information on the number of matches played on each day from 2008 to 2019.
#
# Analysis:
#
#   Overall Growth:
#         The total number of matches played has consistently increased each year, indicating the growing popularity and expansion of the IPL.
#
#    Peak Match Days:
#         The highest number of matches is generally played on Saturdays and Sundays, reflecting a strategic scheduling decision to attract larger audiences during weekends.
#
#    Consistency in Weekend Matches:
#         Throughout the years, Sundays consistently maintain a high number of matches, showcasing the significance of weekends in the IPL schedule.
#
#    Midweek Challenges:
#         Matches played on weekdays (Monday to Thursday) generally have a lower count compared to weekends. This could be due to the practical challenges of attendance and viewership during working days.
#
#    Seasonal Variations:
#         The dataset shows a steady increase in the total number of matches played each season. This suggests that the IPL organizers have been successful in expanding and sustaining interest in the tournament.
#
# Interpretation:
#
#    Audience Engagement:
#         The scheduling strategy of having more matches on weekends aligns with the goal of maximizing audience engagement. Weekends, especially Sundays, are considered prime time for sports viewership.
#
#    Challenges on Weekdays:
#         The lower count of matches on weekdays could be attributed to the challenges of attracting live audiences to the stadiums and viewership on television or online platforms during working days.
#
#    Strategic Planning:
#         The consistent growth in the total number of matches indicates effective planning and management by IPL organizers. This ensures sustained interest and excitement among cricket fans throughout the tournament.
#
#    Weekend Primacy:
#         The preference for Saturdays and Sundays for hosting more matches is a well-thought-out strategy, considering the broader appeal and availability of the audience during weekends.
#
#    Impact of Seasonal Factors:
#         The increasing trend in the number of matches played each season reflects the IPL's ability to adapt to changing preferences and maintain its status as one of the most-watched cricket leagues globally.

# %%
# Use pd.read_excel to read data from a specific sheet
df_stadiums = pd.read_excel(file_name, sheet_name="stadiums")

# Remove the "Row Labels" column
df_stadiums = df_stadiums.drop("Row Labels", axis=1)

# Adjust the figure size to indirectly control bar width
fig_size = (6, 4)  # You can adjust the values based on your preference

# Create the race chart
bcr.bar_chart_race(df=df_stadiums, title="Number of IPL Matches Hosted by Stadiums Over the Years", figsize=fig_size, period_length=1000, period_label={'x': 0.99, 'y': 0.12, 'ha': 'right'},
                    steps_per_period=1, interpolate_period=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="1230" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# Use pd.read_excel to read data from a specific sheet
df_toss_decisions = pd.read_excel(file_name, sheet_name="toss_decisions")

# Remove the "Row Labels" column
df_toss_decisions = df_toss_decisions.drop("Row Labels", axis=1)

# Adjust the figure size to indirectly control bar width
fig_size = (4, 3)  # You can adjust the values based on your preference

# Create the race chart
bcr.bar_chart_race(df=df_toss_decisions, title="Decisions after the Toss Over the Years", figsize=fig_size, period_length=1000, period_label={'x': 0.99, 'y': 0.12, 'ha': 'right'},
                    steps_per_period=1, interpolate_period=False, bar_kwargs={'alpha': 0.7})
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="594" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# Use pd.read_excel to read data from a specific sheet
df_toss_won = pd.read_excel(file_name, sheet_name="toss_won")

# Remove the "Row Labels" column
df_toss_won = df_toss_won.drop("Row Labels", axis=1)

# Adjust the figure size to indirectly control bar width
fig_size = (5, 3)  # You can adjust the values based on your preference

# Create the race chart
bcr.bar_chart_race(df=df_toss_won, title="Number of Tosses Won by IPL Teams Over the Years", figsize=fig_size, period_length=1000, period_label={'x': 0.99, 'y': 0.12, 'ha': 'right'},
                    steps_per_period=1, interpolate_period=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="910" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# Objective:
# The objective of this dataset is to analyze the number of tosses won by each Indian Premier League (IPL) team from 2008 to 2019. Toss winning is considered significant in cricket as the team winning the toss gets to choose whether to bat or bowl first.
#
# Analysis:
#
#   Consistency in Toss Wins:
#         Mumbai Indians (MI) and Kolkata Knight Riders (KKR) have consistently won a significant number of tosses across multiple seasons.
#
#    Rising Pune Supergiants and Kochi Tuskers Kerala:
#         Teams like Rising Pune Supergiants and Kochi Tuskers Kerala had limited appearances in the IPL, leading to fewer toss wins.
#
#    Year-wise Trends:
#         The dataset reflects an increase in the total number of tosses won by teams over the years, potentially indicating the growing competitiveness of the league.
#
#    Toss Dominance:
#         Mumbai Indians (MI) and Chennai Super Kings (CSK) emerge as dominant teams in terms of toss wins, showcasing their overall performance and captaincy influence.
#
#    Balanced Distribution:
#         While there are variations in the number of toss wins, most teams have had a reasonably balanced distribution over the years.
#
# Interpretation:
#
#    Strategic Advantage:
#         Toss-winning teams gain a strategic advantage in deciding whether to bat or bowl first, depending on pitch conditions and team strengths.
#
#    Consistency in Performance:
#         Teams like Mumbai Indians and Kolkata Knight Riders, consistently winning tosses, might have developed effective strategies, contributing to their overall performance in the league.
#
#    Limited Impact on Success:
#         While winning the toss is advantageous, success in the IPL depends on various factors, including player performance, team strategy, and match dynamics. Toss wins alone do not guarantee overall success.
#
#    Team Dominance:
#         Mumbai Indians and Chennai Super Kings, two of the most successful IPL franchises, exhibit dominance not only in match victories but also in winning the toss, showcasing a comprehensive approach to the game.
#
#    Potential Captains' Influence:
#         The dataset indirectly reflects the leadership skills of team captains, as the toss-winning decision is often influenced by the captain's understanding of the game and conditions.
#
# In conclusion, the dataset provides insights into the toss-winning patterns of IPL teams, suggesting strategic advantages and potential leadership strengths. However, it is essential to consider multiple factors contributing to a team's success in the IPL beyond toss wins.

# %%
# Use pd.read_excel to read data from a specific sheet
df_toss_bat = pd.read_excel(file_name, sheet_name="toss_bat")

# Remove the "Row Labels" column
df_toss_bat = df_toss_bat.drop("Row Labels", axis=1)
# Adjust the figure size to indirectly control bar width
fig_size = (3, 3)  # You can adjust the values based on your preference

# Create the race chart for matches played on each day of the week
bcr.bar_chart_race(df=df_toss_bat, title="Teams to choose BAT 1st", figsize=fig_size,
                    period_length=1000, period_label={'x': 0.99, 'y': 0.12, 'ha': 'right'},
                    steps_per_period=1, interpolate_period=False, bar_kwargs={'alpha': 0.7})
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="622" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# Objective:
# To understand the trend of teams winning the toss and choosing to bat in each IPL season.
#
# Analysis:
#
#    Consistency: Some teams, like Mumbai Indians (MI), Chennai Super Kings (CSK), and Kolkata Knight Riders (KKR), consistently opt to bat after winning the toss in multiple seasons.
#
#    Increasing Trend: In general, there is an increasing trend in the number of matches where teams won the toss and chose to bat. This suggests a possible preference for setting a target rather than chasing.
#
#    Variability: The number of matches where a team chose to bat can vary from season to season, indicating that strategies might change based on team composition, conditions, or other factors.
#
# Interpretation:
#
#    The data suggests that, over the years, teams have shown a preference for batting first after winning the toss.
#
#    Teams may choose to set a challenging target, especially if they have confidence in their batting lineup or if they believe that the pitch conditions are favorable for batting early in the match.
#
#    The change in strategies could also be influenced by the specific conditions of the match venue, team strengths, or the nature of the tournament in each season.

# %%
# Use pd.read_excel to read data from a specific sheet
df_toss_field = pd.read_excel(file_name, sheet_name="toss_field")

# Remove the "Row Labels" column
df_toss_field = df_toss_field.drop("Row Labels", axis=1)
# Adjust the figure size to indirectly control bar width
fig_size = (3, 3)  # You can adjust the values based on your preference

# Create the race chart for matches played on each day of the week
bcr.bar_chart_race(df=df_toss_field, title="Teams to choose BOWL 1st", figsize=fig_size,
                    period_length=1000, period_label={'x': 0.99, 'y': 0.12, 'ha': 'right'},
                    steps_per_period=1, interpolate_period=False, bar_kwargs={'alpha': 0.7})
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="622" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# Objective:
# To understand the trend of teams winning the toss and choosing to field in each IPL season.
#
# Analysis:
#
#   Increasing Trend: In general, there is an increasing trend in the number of matches where teams won the toss and chose to field. This suggests a preference for chasing the target rather than setting one.
#
#   Consistency: Some teams, like Mumbai Indians (MI), Chennai Super Kings (CSK), and Kolkata Knight Riders (KKR), consistently opt to field after winning the toss in multiple seasons.
#
#   Variability: The number of matches where a team chose to field can vary significantly from season to season, indicating that strategies might change based on team composition, conditions, or other factors.
#
# Interpretation:
#
#    The data suggests a shift in team strategies towards preferring to chase targets, which is a common trend in limited-overs cricket.
#
#    Teams may choose to field first to have a clear target in mind while batting, allowing them to plan their innings accordingly.
#
#    The change in strategies could also be influenced by the specific conditions of the match venue, team strengths, or the nature of the tournament in each season.
